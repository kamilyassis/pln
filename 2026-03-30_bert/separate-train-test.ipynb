# %%
import pandas as pd

# %%
from sklearn.model_selection import train_test_split

df = pd.read_csv("data/conexao-labels-full-4.1nano-p2.csv", sep='|')
print(df.shape)
df.head()
# Out:
# (12287, 3)
#                                             sentence            label  \
# 0  E certamente com o risco de ser injusto com al...  Loaded_Language
# 1  Queda de 27,5% em relação ao mesmo período do ...         No_Label
# 2  A seguir, são sugeridas algumas medidas de com...         No_Label
# 3  Cito onze aqui:\n– PL 6944/2017: impede a limi...         No_Label
# 4  Um ex-presidente, dos mais populares e populis...  Loaded_Language
#
#                                        justification
# 0  The sentence uses emotionally charged words li...
# 1  The sentences are factual reports and do not c...
# 2  The sentence is informational and describes me...
# 3  The sentence is informational, listing legisla...
# 4  The sentence uses emotionally charged words li...

# %%
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

train_df.to_csv("training_data/conexao-labels-train.csv", index=False, sep='|')
test_df.to_csv("training_data/conexao-labels-test.csv", index=False, sep='|')

# %%
df = pd.read_csv("data/g1-labels-full-4.1nano-p2.csv")
print(df.shape)
display(df.head())

train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)
train_df.to_csv("training_data/g1-labels-train.csv", index=False, sep='|')
test_df.to_csv("training_data/g1-labels-test.csv", index=False, sep='|')
# Out:
# (3668, 3)
#                                             sentence     label  \
# 0  O vídeo foi gravado no cemitério de Annotto Ba...  No_Label
# 1  OFato ou Fakepesquisou pelo cemitério de Annot...  No_Label
# 2  Mas isso não é verdade.OFato ou Fakeenviou o m...  No_Label
# 3  Segundo o ex-ministro do TSE Carlos Horbach, r...  No_Label
# 4  Não há, no texto do ECA Digital, qualquer menç...  No_Label
#
#                                        justification
# 0  The sentence is purely informational, describi...
# 1  The sentence provides factual information abou...
# 2  The sentence primarily relays factual informat...
# 3  The sentence is a detailed explanation of a le...
# 4  The sentence provides an informational clarifi...
